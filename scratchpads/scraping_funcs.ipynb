# %%
import pandas as pd
import sys
from bs4 import BeautifulSoup, SoupStrainer, NavigableString
import requests
from PandasBasketball.stats import player_stats, player_gamelog

# %%
sys.path.insert(0, "/Users/samdillard/python/github.com/samhld/nba_stats/app/")

# %%
from scraper.getters import get_player_dict
# from relational.getters import get_players_tables

# %%
player_dict = get_player_dict()
player_dict
# Out:
# {'Alaa Abdelnaby': 'abdelal01',
#  'Zaid Abdul-Aziz': 'abdulza01',
#  'Kareem Abdul-Jabbar': 'abdulka01',
#  'Mahmoud Abdul-Rauf': 'abdulma02',
#  'Tariq Abdul-Wahad': 'abdulta01',
#  'Shareef Abdur-Rahim': 'abdursh01',
#  'Tom Abernethy': 'abernto01',
#  'Forest Able': 'ablefo01',
#  'John Abramovic': 'abramjo01',
#  'Álex Abrines': 'abrinal01',
#  'Precious Achiuwa': 'achiupr01',
#  'Alex Acker': 'ackeral01',
#  'Don Ackerman': 'ackerdo01',
#  'Mark Acres': 'acresma01',
#  'Bud Acton': 'actonbu01',
#  'Quincy Acy': 'acyqu01',
#  'Alvan Adams': 'adamsal01',
#  'Don Adams': 'adamsdo01',
#  'George Adams': 'adamsge01',
#  'Hassan Adams': 'adamsha01',
#  'Jaylen Adams': 'adamsja01',
#  'Jordan Adams': 'adamsjo01',
#  'Michael Adams': 'adamsmi01',
#  'Steven Adams': 'adamsst01',
#  'Rafael Addison': 'addisra01',
#  'Bam Adebayo': 'adebaba01',
#  'Deng Adel': 'adelde01',
#  'Rick Adelman': 'adelmri01',
#  'Jeff Adrien': 'adrieje01',
#  'Arron Afflalo': 'afflaar01',
# ...

# %%
import requests_cache
import html5lib
import re

# %%
requests_cache.install_cache('request_cache')

# %%
url = "https://www.basketball-reference.com/players/j/jamesle01.html"
res = requests.get(url)

# %%
soup = BeautifulSoup(res.content, 'lxml')
table = soup.find("table")
table
# Out:
# <table class="row_summable sortable stats_table" data-cols-to-freeze="1,3" id="per_game"><caption>Per Game Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr>
# <th aria-label="If listed as single number, the year the season ended.★ - Indicates All-Star for league.Only on regular season tables." class="poptip sort_default_asc center" data-stat="season" data-tip="If listed as single number, the year the season ended.&lt;br&gt;★ - Indicates All-Star for league.&lt;br&gt;Only on regular season tables." scope="col">Season</th>
# <th aria-label="Player's age on February 1 of the season" class="poptip sort_default_asc center" data-stat="age" data-tip="Player's age on February 1 of the season" scope="col">Age</th>
# ...

# %%
columns = []
heading = table.find("thead")
heading_row = heading.find("tr")
heading_row.find_all("th")[-1].text
# for x in heading_row.find_all("th"):
#     columns.append(x.string)
# Out:
# 'PTS'

# %%
body = table.find("tbody")
rows = body.find_all("tr")
rows[-1]
# Out:
# <tr class="full_table" id="per_game.2021"><th class="left" data-stat="season" scope="row"><a href="/players/j/jamesle01/gamelog/2021/">2020-21</a></th><td class="center" data-stat="age">36</td><td class="left" data-stat="team_id"><a href="/teams/LAL/2021.html">LAL</a></td><td class="left" data-stat="lg_id"><a href="/leagues/NBA_2021.html">NBA</a></td><td class="center" data-stat="pos">PG</td><td class="right" data-stat="g"><strong>12</strong></td><td class="right" data-stat="gs">12</td><td class="right" data-stat="mp_per_g">32.3</td><td class="right" data-stat="fg_per_g">8.9</td><td class="right" data-stat="fga_per_g">18.3</td><td class="right" data-stat="fg_pct">.486</td><td class="right" data-stat="fg3_per_g">2.3</td><td class="right" data-stat="fg3a_per_g">6.3</td><td class="right" data-stat="fg3_pct">.360</td><td class="right" data-stat="fg2_per_g">6.7</td><td class="right" data-stat="fg2a_per_g">12.1</td><td class="right" data-stat="fg2_pct">.552</td><td class="right" data-stat=
# ...

# %%
def get_last_table_row(table):
    body = table.find("tbody")
    rows = body.find_all("tr")
    return rows[-1]
get_last_table_row(table)
# Out:
# <tr class="full_table" id="per_game.2021"><th class="left" data-stat="season" scope="row"><a href="/players/j/jamesle01/gamelog/2021/">2020-21</a></th><td class="center" data-stat="age">36</td><td class="left" data-stat="team_id"><a href="/teams/LAL/2021.html">LAL</a></td><td class="left" data-stat="lg_id"><a href="/leagues/NBA_2021.html">NBA</a></td><td class="center" data-stat="pos">PG</td><td class="right" data-stat="g"><strong>12</strong></td><td class="right" data-stat="gs">12</td><td class="right" data-stat="mp_per_g">32.3</td><td class="right" data-stat="fg_per_g">8.9</td><td class="right" data-stat="fga_per_g">18.3</td><td class="right" data-stat="fg_pct">.486</td><td class="right" data-stat="fg3_per_g">2.3</td><td class="right" data-stat="fg3a_per_g">6.3</td><td class="right" data-stat="fg3_pct">.360</td><td class="right" data-stat="fg2_per_g">6.7</td><td class="right" data-stat="fg2a_per_g">12.1</td><td class="right" data-stat="fg2_pct">.552</td><td class="right" data-stat=
# ...

# %%
def get_last_df_row(df):
    return df.iloc[-1]
    rows = body.find_all("tr")
    return rows[-1]

# %%
url = "https://www.basketball-reference.com/players/j/jamesle01.html"
bron = player_stats(res, "per_game")
last_row = bron.iloc[-1]
rest_rows = bron[:-1]
rest_rows
# Out:
#      Season Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...   FT%  ORB  DRB  \
# 0   2003-04  19  CLE  NBA  SG  79  79  39.5   7.9  18.9  ...  .754  1.3  4.2
# 1   2004-05  20  CLE  NBA  SF  80  80  42.4   9.9  21.1  ...  .750  1.4  6.0
# 2   2005-06  21  CLE  NBA  SF  79  79  42.5  11.1  23.1  ...  .738  0.9  6.1
# 3   2006-07  22  CLE  NBA  SF  78  78  40.9   9.9  20.8  ...  .698  1.1  5.7
# 4   2007-08  23  CLE  NBA  SF  75  74  40.4  10.6  21.9  ...  .712  1.8  6.1
# 5   2008-09  24  CLE  NBA  SF  81  81  37.7   9.7  19.9  ...  .780  1.3  6.3
# 6   2009-10  25  CLE  NBA  SF  76  76  39.0  10.1  20.1  ...  .767  0.9  6.4
# 7   2010-11  26  MIA  NBA  SF  79  79  38.8   9.6  18.8  ...  .759  1.0  6.5
# 8   2011-12  27  MIA  NBA  SF  62  62  37.5  10.0  18.9  ...  .771  1.5  6.4
# 9   2012-13  28  MIA  NBA  PF  76  76  37.9  10.1  17.8  ...  .753  1.3  6.8
# 10  2013-14  29  MIA  NBA  PF  77  77  37.7  10.0  17.6  ...  .750  1.1  5.9
# ...

# %%
from preprocessor.mungers import append_row

# %%
PLAYER_DICT = player_dict
full_df = append_row(last_row, rest_rows, to_top=False)
full_df
# Out:
#      Season Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...   FT%  ORB  DRB  \
# 0   2003-04  19  CLE  NBA  SG  79  79  39.5   7.9  18.9  ...  .754  1.3  4.2
# 1   2004-05  20  CLE  NBA  SF  80  80  42.4   9.9  21.1  ...  .750  1.4  6.0
# 2   2005-06  21  CLE  NBA  SF  79  79  42.5  11.1  23.1  ...  .738  0.9  6.1
# 3   2006-07  22  CLE  NBA  SF  78  78  40.9   9.9  20.8  ...  .698  1.1  5.7
# 4   2007-08  23  CLE  NBA  SF  75  74  40.4  10.6  21.9  ...  .712  1.8  6.1
# 5   2008-09  24  CLE  NBA  SF  81  81  37.7   9.7  19.9  ...  .780  1.3  6.3
# 6   2009-10  25  CLE  NBA  SF  76  76  39.0  10.1  20.1  ...  .767  0.9  6.4
# 7   2010-11  26  MIA  NBA  SF  79  79  38.8   9.6  18.8  ...  .759  1.0  6.5
# 8   2011-12  27  MIA  NBA  SF  62  62  37.5  10.0  18.9  ...  .771  1.5  6.4
# 9   2012-13  28  MIA  NBA  PF  76  76  37.9  10.1  17.8  ...  .753  1.3  6.8
# 10  2013-14  29  MIA  NBA  PF  77  77  37.7  10.0  17.6  ...  .750  1.1  5.9
# ...
