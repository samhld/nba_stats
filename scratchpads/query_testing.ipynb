# %%
import sys
import requests_cache

# %%
sys.path.insert(0, "/Users/samdillard/python/github.com/samhld/nba_stats/app/")
requests_cache.install_cache('request_cache')

# %%
from scraper import getters
from preprocessor import builders

# %%
per_game_first_50 = builders.create_all_player_stats_df(segment=slice(0,50))
per_game_first_50
# Out:
# DF for: http://www.basketball-reference.com/players/a/abdelal01.html
# DF for: http://www.basketball-reference.com/players/a/abdulza01.html
# DF for: http://www.basketball-reference.com/players/a/abdulka01.html
# DF for: http://www.basketball-reference.com/players/a/abdulma02.html
# DF for: http://www.basketball-reference.com/players/a/abdulta01.html
# DF for: http://www.basketball-reference.com/players/a/abdursh01.html
# DF for: http://www.basketball-reference.com/players/a/abernto01.html
# DF for: http://www.basketball-reference.com/players/a/ablefo01.html
# DF for: http://www.basketball-reference.com/players/a/abramjo01.html
# DF for: http://www.basketball-reference.com/players/a/abrinal01.html
# DF for: http://www.basketball-reference.com/players/a/achiupr01.html
# DF for: http://www.basketball-reference.com/players/a/ackeral01.html
# DF for: http://www.basketball-reference.com/players/a/ackerdo01.html
# DF for: http://www.basketball-reference.com/players/a/acresma01.html
# ...

# %%
afflalo_dubs = per_game_first_50.loc["Arron Afflalo"]
afflalo[afflalo["Tm"] == "GSW"]
# Out:
#     Season Age   Tm   Lg Pos   G GS   MP   FG  FGA  ...   FT%  ORB  DRB   TRB  \
# 0  2010-11  24  GSW  NBA  PF  23  0  196  4.2  9.9  ...  .579  4.2  6.4  10.7
#
#    AST  STL  BLK  TOV   PF   PTS
# 0  1.8  0.7  0.9  1.7  5.1  10.5
#
# [1 rows x 29 columns]

# %%
players = per_game_first_50.index.get_level_values(0).unique()
first_10 = per_game_first_50.loc[list(players[:10])].head(50)
first_10.xs("Kareem Abdul-Jabbar")
# Out:
#      Season Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...   FT%  ORB   DRB  \
# 0   1969-70  22  MIL  NBA   C  82      3534   9.6  18.4  ...  .653
# 1   1970-71  23  MIL  NBA   C  82      3288  11.6  20.2  ...  .690
# 2   1971-72  24  MIL  NBA   C  81      3583  11.6  20.3  ...  .689
# 3   1972-73  25  MIL  NBA   C  76      3254  10.9  19.6  ...  .713
# 4   1973-74  26  MIL  NBA   C  81      3548   9.6  17.8  ...  .702  2.9   9.0
# 5   1974-75  27  MIL  NBA   C  65      2747  10.6  20.8  ...  .763  2.5   9.4
# 6   1975-76  28  LAL  NBA   C  82      3379   9.7  18.4  ...  .703  2.9  11.8
# 7   1976-77  29  LAL  NBA   C  82      3016  10.6  18.3  ...  .701  3.2   9.8
# 8   1977-78  30  LAL  NBA   C  62      2265  10.5  19.2  ...  .783  3.0   9.8
# 9   1978-79  31  LAL  NBA   C  80      3157   8.9  15.4  ...  .736  2.4   9.3
# 10  1979-80  32  LAL  NBA   C  82      3143   9.6  15.8  ...  .765  2.2   8.0
# 11  1980-81  33  LAL  NBA   C  80      2976  10.1  17.6  ...  .766  2.4   7.5
# ...

# %%
# adv = builders.create_all_player_stats_df(stat="advanced")
# adv.head()

# %%
# adv.sort_values("WS/48", ascending=False)

# %%
# adv[:50].compare(adv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-721162601948> in <module>
# ----> 1 adv[:50].compare(adv)
#
# NameError: name 'adv' is not defined

# %%
# Get first year stats for list of players
player_slice = slice("Zaid Abdul-Aziz","Mahmoud Abdul-Rauf")
rookie_year_slice = slice(0)
first_10.loc[(player_slice,rookie_year_slice),:].sort_values("PTS", ascending=False)
# Out:
#                         Season Age   Tm   Lg Pos   G  GS    MP    FG   FGA  \
# Kareem Abdul-Jabbar 0  1969-70  22  MIL  NBA   C  82      3534   9.6  18.4
# Mahmoud Abdul-Rauf  0  1990-91  21  DEN  NBA  PG  67  19  1505  10.0  24.1
# Zaid Abdul-Aziz     0  1968-69  22  TOT  NBA   C  49       945   5.5  14.9
#
#                        ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF  \
# Kareem Abdul-Jabbar 0  ...  .653            12.1  3.4                 2.9
# Mahmoud Abdul-Rauf  0  ...  .857  0.8  2.1   2.9  4.9  1.3  0.1  2.6  3.6
# Zaid Abdul-Aziz     0  ...  .619            15.6  1.4                 4.4
#
#                         PTS
# Kareem Abdul-Jabbar 0  24.1
# Mahmoud Abdul-Rauf  0  22.5
# Zaid Abdul-Aziz     0  13.6
#
# [3 rows x 29 columns]
